# %%
import pandas as pd
from tqdm.notebook import tqdm
import re
import string
from indoNLP.preprocessing import *
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
df = pd.read_csv('../dataset/KaggleReview.csv')

# %%
def ratingToSentiment(row):
  sentiment = -1
  # print(row, row['Review'])
  if (row['Rating'] <= 2):
    sentiment = 0
  elif (row['Rating'] == 3):
    sentiment = 1
  else:
    sentiment = 2
  return sentiment

df['Sentiment'] = df.apply(ratingToSentiment, axis=1)

# %%
def get_stopwords(file_path):
  stopwords=[]
  file_stopwords = open(file_path,'r')
  row = file_stopwords.readline()
  while row:
      word = row.strip()
      stopwords.append(word)
      row = file_stopwords.readline()
  file_stopwords.close()
  return stopwords

def handle_stopwords(review, stopwords):
  feature_vector = []
  review = review.split(' ')
  for word in review:
    val = re.search(r"^[a-zA-Z][a-zA-Z0-9]*$", word) #menghilangkan karakter selain huruf didalam kata
    if (word in stopwords or val is None):
      continue
    else:
      feature_vector.append(word)
  for_stemming = ' '.join(feature_vector)
  return feature_vector, for_stemming

def handle_negative(review):
  negative_review = []
  review = review.split(' ')
  for i in range(len(review)):
    word = review[i]
    if review[i-1] != 'enggak':
      negative_review.append(word)
    else:
      word = 'tidak_'+word
      negative_review.append(word)
  for_stemming = ' '.join(negative_review)
  return for_stemming

# %%
# Remove emoji, punctuation, symbol
def preprocess(text):
  # Casefolding to Lowercase
  text = text.lower()

  # Remove punctuation
  text = text.translate(str.maketrans('', '', string.punctuation))

  text = replace_word_elongation(text)  # replace WE

  # Change emoji to words
  # text = emoji_to_words(text)
  text = text.translate(str.maketrans(string.punctuation, " " * len(string.punctuation)))

  # Remove HTML tags
  text = remove_html(text) 
  text = remove_url(text)  # remove url
  text = replace_slang(text)  # replace slang words

  file_path ='../dataset/stopwords-indo.txt'
  stopwords = get_stopwords(file_path)
  feature, text = handle_stopwords(text, stopwords)
  text = handle_negative(text)

  # Remove numbers
  text = text.translate(str.maketrans('', '', string.digits))
  # Remove whitespaces at front and back
  text = ' '.join(text.split())

  # Stemming
  factory = StemmerFactory()
  stemmer = factory.create_stemmer()
  text = stemmer.stem(text)
  return text

# %%
df["Cleaned"] = [preprocess(x) for x in tqdm(df['Review'].values)]
# Out:
#   0%|          | 0/8646 [00:00<?, ?it/s]

# %%
senticnet = pd.read_excel('senticnet.xlsx')
senticnet.head()
# Out:
#           CONCEPT  INTROSPECTION  TEMPER  ATTITUDE  SENSITIVITY  \
# 0             aah         -0.514     0.0     0.000        0.000
# 1           abadi          0.000     0.0     0.918        0.000
# 2  abdominoplasti          0.000     0.0     0.232        0.000
# 3        aberrate          0.000     0.0    -0.564        0.000
# 4            abey          0.000     0.0     0.000       -0.329
#
#   PRIMARY EMOTION SECONDAY EMOTION POLARITY VALUE  POLARITY INTENSITY  \
# 0        #sadness              NaN       negative              -0.514
# 1        #delight              NaN       positive               0.918
# 2     #acceptance              NaN       positive               0.232
# 3        #disgust              NaN       negative              -0.564
# 4        #anxiety              NaN       negative              -0.329
#
#         SEMANTICS             Unnamed: 10                Unnamed: 11  \
# 0         berlari            absquatulate               li_na_lamont
# 1           elang       permukaan_trotoar  pahlawan_tanpa_tanda_jasa
# 2         lelucon   mengemudi_dengan_aman                  off_color
# 3  gelembung_warp            warp_repulse                   warp_tug
# 4           hemat  penghargaan_pascabayar              setelan_bagus
#
#       Unnamed: 12                Unnamed: 13
# 0        intisari                       deru
# 1           elite           tunica_albuginea
# 2      buruh_tani  menimbulkan_korosi_tungau
# 3           tekuk            membungkuk_slub
# 4  tradisi_rakyat            mollify_tantrum

# %%
senticnet_dict = dict(zip(senticnet['CONCEPT'], senticnet['POLARITY INTENSITY']))
senticnet_dict
# Out:
# {'aah': -0.514,
#  'abadi': 0.918,
#  'abdominoplasti': 0.232,
#  'aberrate': -0.564,
#  'abey': -0.329,
#  'abeyance_berair': 0.205,
#  'ablare': -0.976,
#  'ablasi_eyestalk': -0.832,
#  'ablasi_kateter': -0.921,
#  'ablast': -0.895,
#  'abnormal': -0.299,
#  'abomasum': -0.27,
#  'abortifasient': 0.554,
#  'abortisida': -0.883,
#  'aboulia': -0.978,
#  'aboulik': 0.885,
#  'abrasi': -0.194,
#  'abreaksi': 0.528,
#  'absen': -0.978,
#  'absentmind': -0.846,
#  'absis': -0.844,
#  'absolutepunk': -0.652,
#  'absolutif': -0.877,
#  'absolutist': -0.86,
#  'absolvitasi': 0.93,
#  'absquatulate': -0.872,
#  'abstain_dari': -0.489,
#  'abstensi': 0.505,
#  'abstraktif': -0.811,
#  'abu_abu': -0.306,
#  'abu_abu_belang': -0.861,
#  'abu_abu_silver': 0.569,
#  'abu_abu_suram': -0.488,
#  'abulia': -0.891,
#  'ac_id': -0.838,
#  'acak': -0.863,
#  'acalculia': -0.644,
#  'acanthamoeba': -0.183,
#  'acanthocephalan': -0.838,
#  'acara_sosial': 0.562,
#  'acara_sosial_meromorfik': -0.825,
#  'acaricide': -0.483,
#  'acausal': 0.792,
#  'accelerator_proton': -0.865,
#  'ace_in_hole': 0.951,
#  'ace_payudara': 0.234,
#  'ace_sooty': 0.849,
#  'ace_up_sleeve': 0.85,
#  'acedia_bear': -0.61,
#  'acerate': 0.861,
#  'acerb_hyaluronic': 0.994,
#  'acerose': 0.803,
#  'acesulfame_potassium': -0.57,
#  'acetabulum': 0.683,
#  'acetazolamide': -0.914,
#  'acetobacter': -0.964,
#  'ache': -0.911,
#  'achene': 0.223,
#  'acheronian': -0.842,
#  'acherontik': -0.847,
#  'achilles': 0.809,
#  'achlorhydria': -0.522,
#  'achondroplasia': -0.84,
#  'achromasia': -0.648,
#  'acicular': 0.823,
#  'acidophil': 0.826,
#  'acidophilus': -0.896,
#  'acidophilus_microflora': -0.885,
#  'aciduria': 0.899,
#  'acipic_acerb': 0.911,
#  'ack': 0.79,
#  'ackee': 0.189,
#  'acnielsen': 0.975,
#  'aconite': 0.658,
#  'acquisite': -0.329,
#  'acral': -0.838,
#  'acrobatic_varsity': -0.839,
#  'acroread': 0.863,
#  'actias_luna': 0.273,
#  'actus_reus': -0.582,
#  'acuh_tak_acuh': -0.329,
#  'ad_lib': 0.867,
#  'ada': 0.914,
#  'adalah': -0.899,
#  'adalah_dc': 0.838,
#  'adalah_deender': -0.291,
#  'adalah_kejutan': -0.831,
#  'adalah_sithoth': 0.867,
#  'adas': 0.835,
#  'adas_liar': 0.296,
#  'adas_manis': 0.896,
#  'adas_manis_hisop': 0.545,
#  'adas_perunggu': 0.64,
#  'adat': 0.804,
#  'adcirca': -0.521,
#  'adduksi': -0.599,
#  'adegan_perkelahian_gadis': -0.313,
#  'adelgid': 0.321,
#  'adenocarcinoma_mucinous': -0.893,
#  'adenofilum': -0.807,
#  'adenokarsinoma': -0.993,
#  'adenoma': -0.995,
#  'adenoma_hipofisis': 0.83,
#  'adenoma_pleomorfik': 0.968,
#  'adenopati': -0.879,
#  'adhd': -0.171,
#  'adhesi': 0.842,
#  'adhesin': -0.869,
#  'adiabatik': 0.509,
#  'adik': -0.578,
#  'adil': 0.329,
#  'adipic_tajam': 0.925,
#  'adipic_virulen': 0.965,
#  'adipic_zen': 0.898,
#  'adipocere': -0.857,
#  'adiponektin': -0.974,
#  'adiponitrile': 0.854,
#  'adiposa': -0.817,
#  'adiposa_asam': 0.934,
#  'adit_up': -0.543,
#  'aditif': 0.142,
#  'aditif_bulanan': 0.888,
#  'aditif_makanan': -0.596,
#  'aditif_vesicant': 0.927,
#  'aditif_vesikator': 0.975,
#  'aditif_yang_buruk': 0.929,
#  'aditif_yang_tidak_diinginkan': 0.896,
#  'adium': 0.194,
#  'adler': -0.694,
#  'admissable': 0.246,
#  'admissive': 0.235,
#  'adnexal': -0.918,
#  'adonan': -0.602,
#  'adonan_angin': -0.841,
#  'adonan_blotto': 0.217,
#  'adonan_filo': -0.254,
#  'adonan_fosfat_backbone': 0.203,
#  'adonan_kasar': -0.499,
#  'adonan_ketat': 0.205,
#  'adonan_looper': 0.237,
#  'adonan_submus': 0.205,
#  'adonan_tanah_liat': 0.215,
#  'adrenal': -0.837,
#  'adrenalin': 0.891,
#  'adrenalin_epinefrin': 0.826,
#  'adrenalin_yang_sublimasi': 0.889,
#  'adrenergik': 0.838,
#  'adrenokortikal': -0.855,
#  'adrenokrom': 0.815,
#  'adric': 0.873,
#  'adsorpsi_gas': 0.809,
#  'adsorptif': 0.891,
#  'aduh': -0.324,
#  'advektif': 0.714,
#  'adventif': 0.895,
#  'adverbia': 0.888,
#  'adverten': 0.862,
#  'advil': -0.823,
#  'advokasi_percobaan': -0.822,
#  'advokat': -0.849,
#  'advokat_yang_sulit': 0.844,
#  'advokat_yang_tak_kenal_lelah': 0.873,
#  'aedicule': 0.205,
#  'aegir': 0.866,
#  'aegle': -0.794,
#  'aeolis_mons_meningkat': -0.506,
#  'aeolotropik': -0.556,
#  'aequorea': -0.885,
#  'aequorin': -0.956,
#  'aerdrie_faenya': -0.504,
#  'aerdy': -0.903,
#  'aero': -0.165,
#  'aerobatik': -0.93,
#  'aerobee': -0.846,
#  'aerobik': 0.832,
#  'aerodinamis': 0.859,
#  'aeroshell': -0.888,
#  'aerostat': -0.892,
#  'aerotoler': 0.843,
#  'aeruginosa': -0.847,
#  'aery': -0.891,
#  'aery_assault': -0.141,
#  'aery_sinematografi': -0.931,
#  'aeschylus_oresteia': 0.821,
#  'aesculapian_ganja': -0.83,
#  'aesculapian_profesional': 0.653,
#  'aesculapian_record': 0.932,
#  'aestesi': 0.673,
#  'aestivate': -0.817,
#  'aestivation': -0.841,
#  'aether_luminiferous': 0.799,
#  'aethiophysa': -0.577,
#  'afasia': -0.56,
#  'afasia_anomik': -0.607,
#  'afasia_cairan': -0.645,
#  'afasia_nominal': -0.653,
#  'afasia_pendengaran': -0.645,
#  'aferen': 0.84,
#  'afficionado': 0.848,
#  'affine': 0.659,
#  'afiks': 0.891,
#  'afiksasi': -0.835,
#  'afiliasi': 0.831,
#  'aflatoksin': 0.537,
#  'aflcio': 0.857,
#  'afri_cola': -0.49,
#  'afro_jazz_kuba': 0.861,
#  'afromontan': -0.881,
#  'afterdamp': -0.134,
#  'afterimage': 0.506,
#  'afusi': 0.847,
#  'againe': 0.85,
#  'agak_baru': -0.138,
#  'agak_bodoh': -0.803,
#  'agak_mabuk': -0.306,
#  'agak_menonton': -0.848,
#  'agak_tinggi': 0.812,
#  'agalactiae': -0.483,
#  'agama_abadi': -0.906,
#  'agama_katolik': -0.516,
#  'agama_monoteis': 0.979,
#  'agamawan': -0.831,
#  'agar_agar': 0.209,
#  'agarose': 0.207,
#  'agas': 0.217,
#  'agathe_tyche': 0.692,
#  'agave_nectar': 0.876,
#  'agayne': 0.845,
#  'agaynst': 0.876,
#  'ageism': -0.89,
#  'agen_anorektik': -0.865,
#  'agen_antihipertensi': -0.85,
#  'agen_antimikotik': 0.675,
#  'agen_bersih': 0.824,
#  'agen_bulking': 0.521,
#  'agen_cerdas': 0.853,
#  'agen_denda': 0.177,
#  'agen_favorit': 0.912,
#  'agen_federal_favorit': 0.848,
#  'agen_federal_inotropik': 0.871,
#  'agen_federal_perekat': 0.199,
#  'agen_federal_spionase': 0.794,
#  'agen_inotropik': 0.852,
#  'agen_interpol': 0.868,
#  'agen_jeruk': -0.883,
#  'agen_keratolitik': -0.854,
#  'agen_kolinergik': -0.525,
#  'agen_lakrimasi': -0.852,
#  'agen_lamisil': 0.652,
#  'agen_lisosomotropik': 0.531,
#  'agen_mustard': -0.877,
#  'agen_patuh': 0.202,
#  'agen_pembasah': -0.49,
#  'agen_penggiring': -0.897,
#  'agen_penyakit_air': -0.172,
#  'agen_perekat': 0.168,
#  'agen_pitchy': 0.175,
#  'agen_prokinetik': -0.208,
#  'agen_prokinetik_baru': -0.227,
#  'agen_prokinetik_baru_baru_ini': -0.186,
#  'agen_prokinetik_bodoni': -0.211,
#  'agen_rahasia': 0.823,
#  'agen_saraf': -0.869,
#  'agen_saraf_yang_merusak': -0.877,
#  'agen_spionase': 0.81,
#  'agen_terapi': -0.877,
#  'agen_thixotropic': -0.942,
#  'agen_trombolitik': -0.997,
#  'agenda_persembunyian': -0.869,
#  'agent_orange': -0.845,
#  'aggrandizing': -0.557,
#  'aggro': -0.648,
#  'agiotage': 0.875,
#  'agitprop': -0.963,
#  'agkistrodon': 0.545,
#  'aglitter': -0.939,
#  'aglomerat_saya': -0.549,
#  'aglow_fluve': 0.993,
#  'agn': 0.843,
#  'agnate': -0.164,
#  'agnatis': -0.89,
#  'agnise': 0.184,
#  'agnize': 0.192,
#  'agnosia': -0.545,
#  'agnosia_eksterosepsi': -0.509,
#  'agnosia_verbal_eksterosepsi': -0.502,
#  'agnostisme': 0.987,
#  'agobot': 0.316,
#  'agonis': -0.835,
#  'agonisme': 0.659,
#  'agramon': 0.822,
#  'agraphia': -0.578,
#  'agregat': 0.131,
#  'agregat_kepanduan': 0.842,
#  'agromania': 0.85,
#  'agronomi': 0.221,
#  'ague_malnutrisi': -0.917,
#  'ague_schizophrenia': -0.202,
#  'agunan': 0.837,
#  'agunan_onset': 0.929,
#  'agung': 0.832,
#  'ah': -0.829,
#  'aha': 0.904,
#  'ahab': -0.606,
#  'ahamkara': 0.84,
#  'ahem': 0.167,
#  'ahh': 0.544,
#  'ahi_tuna': 0.185,
#  'ahl_di_luar_ruangan': 0.164,
#  'ahli': 0.863,
#  'ahli_alkimia': 0.852,
#  'ahli_anggar': -0.993,
#  'ahli_bicara_perut': -0.869,
#  'ahli_botani': 0.816,
#  'ahli_dialektika': 0.858,
#  'ahli_epidemiologi': -0.882,
#  'ahli_hidrografi': -0.931,
#  'ahli_horologi': 0.805,
#  'ahli_ilmu_burung': -0.921,
#  'ahli_kimia': 0.809,
#  'ahli_kimia_fisik': 0.853,
#  'ahli_kimia_mineral': 0.892,
#  'ahli_kraniologi': 0.87,
#  'ahli_kripto': 0.892,
#  'ahli_memperbarui_sesuatu': 0.828,
#  'ahli_nujum': -0.544,
#  'ahli_pengusahaan_lebah': -0.85,
#  'ahli_phrenologist': 0.905,
#  'ahli_pidato': 0.839,
#  'ahli_sejarah_bizantium': 0.668,
#  'ahli_sihir': -0.833,
#  'ahli_teori': 0.961,
#  'ahli_teori_interpersonal': 0.972,
#  'ahli_ulnar': -0.398,
#  'ahli_virologi': 0.646,
#  'ahriman': -0.857,
#  'ahura_mazda': 0.212,
#  'aid_dan_abet': -0.994,
#  'aids': -0.914,
#  'aikido': 0.528,
#  'aimar_dan_ke_darah': -0.812,
#  'air': 0.714,
#  'air_anoksik': 0.813,
#  'air_bah': -0.21,
#  'air_beku': -0.227,
#  'air_berduri': 0.265,
#  'air_berkilau': -0.859,
#  'air_berminyak_panas': 0.968,
#  'air_bijak': 0.828,
#  'air_boo': 0.862,
#  'air_botol': 0.843,
#  'air_cair': 0.201,
#  'air_caltrop': 0.825,
#  'air_cepat': 0.865,
#  'air_cologne': 0.228,
#  'air_cotai': 0.188,
#  'air_cucian': -0.148,
#  'air_dalam': -0.867,
#  'air_datar': 0.875,
#  'air_deionisasi': -0.909,
#  'air_di_bawah_jembatan': -0.808,
#  'air_dingin_glasial': -0.827,
#  'air_dingin_yang_dingin': -0.863,
#  'air_garam': -0.823,
#  'air_glasial': -0.161,
#  'air_gula': 0.887,
#  'air_hangat': -0.908,
#  'air_hidran_panas': 0.865,
#  'air_intercept_panas': 0.893,
#  'air_jatuh': 0.311,
#  'air_keran_baru': 0.879,
#  'air_keran_panas': 0.881,
#  'air_keran_sweltry': 0.865,
#  'air_keran_yang_bagus': 0.846,
#  'air_laut': -0.871,
#  'air_lelehan_glasial': -0.877,
#  'air_limau': -0.829,
#  'air_limbah': -0.534,
#  'air_liur': 0.927,
#  'air_mancur': 0.847,
#  'air_mata': -0.804,
#  'air_mata_bertiup': -0.989,
#  'air_mata_brengsek': -0.492,
#  'air_mata_membenci': -0.879,
#  'air_mata_yanker': -0.962,
#  'air_mendidih': 0.868,
#  'air_panas': -0.848,
#  'air_panas_kepenuhan': 0.955,
#  'air_panas_meminta': 0.802,
#  'air_panas_mohon': 0.885,
#  'air_parit': -0.138,
#  'air_pasang': 0.953,
#  'air_payau': -0.805,
#  'air_pemogokan_panas': 0.888,
#  'air_penyadapan_panas': 0.804,
#  'air_perbani': 0.508,
#  'air_perkolasi': 0.24,
#  'air_pipa': 0.849,
#  'air_pori': -0.879,
#  'air_raksa': -0.861,
#  'air_sabun_baru': 0.905,
#  'air_sabun_panas': 0.904,
#  'air_sabun_swely': 0.93,
#  'air_sabun_yang_bagus': 0.871,
#  'air_seni': -0.505,
#  'air_seni_keran_panas': 0.855,
#  'air_seni_sabun_panas': 0.891,
#  'air_shoal': -0.22,
#  'air_surut': 0.52,
#  'air_tanah': 0.882,
#  'air_tanah_bebas_dari_tuduhan': -0.852,
#  'air_tanah_kosong': -0.899,
#  'air_tanah_payau': 0.31,
#  'air_tapak': 0.844,
#  'air_tapdance_panas': 0.9,
#  'air_tepung': 0.199,
#  'air_terjun_beku': 0.264,
#  'air_tinggi': 0.882,
#  'air_tip_panas': 0.864,
#  'air_turun': -0.85,
#  'air_umpan': 0.86,
#  'air_yang_berbusa': 0.49,
#  'air_yang_diklorinasi': -0.181,
#  'airboat': -0.808,
#  'airbrush': 0.667,
#  'airfoil': 0.162,
#  'airgialla': 0.9,
#  'airhead': -0.952,
#  'airhorn': 0.861,
#  'airily': 0.503,
#  'airlock': -0.869,
#  'airpark': 0.198,
#  'airpocalypse': -0.233,
#  'airwalk': -0.718,
#  'airworth': 0.649,
#  'airy_metal': 0.162,
#  'ajaib': 0.862,
#  'ajaran_mach': 0.871,
#  'ajudan': -0.836,
#  'akademi': 0.845,
#  'akal_bulus': -0.871,
#  'akal_sehat': 0.959,
#  'akalasia': 0.83,
#  'akan_datang': 0.617,
#  'akan_kayu': -0.881,
#  'akan_kekuatan': 0.999,
#  'akan_memiliki': 0.885,
#  'akan_segera_dimulai': 0.826,
#  'akan_soda_brengsek': 0.974,
#  'akar': 0.657,
#  'akar_darah': 0.183,
#  'akar_pahit': 0.155,
#  'akar_rumput': 0.817,
#  'akathisia': -0.273,
#  'aker_bersih': 0.823,
#  'akhir_karir': -0.9,
#  'akhir_musim_gugur': 0.249,
#  'akhir_musim_semi': 0.183,
#  'akhir_otorisasi': -0.497,
#  'akhir_pekan': 0.548,
#  'akhir_permainan': 0.162,
#  'akhirat': 0.943,
#  'akhiri_dengan_solid': 0.846,
#  'akhiri_petualangan': -0.802,
#  'akhirnya': -0.3,
#  'akhromatis': -0.184,
#  'akibat': -0.245,
#  'akibat_wajar': 0.877,
#  'aklamasi': 0.801,
#  'akomodasi': -0.509,
#  'akomodasi_murah': -0.892,
#  'akord': 0.326,
#  'akrab': 0.659,
#  'akrobat': 0.84,
#  'akromion': 0.633,
#  'akronim': -0.252,
#  'akrotomofilia': -0.522,
#  'akseleran': -0.802,
#  'akselerator_angkat_berat': -0.168,
#  'akselerator_kontras': -0.208,
#  'akselerometer': 0.861,
#  'akses_kontrol': 0.196,
#  'aksial': 0.867,
#  'aksiologis': -0.99,
#  'aksioma': 0.226,
#  'aksotomi': -0.538,
#  'aktor': 0.937,
#  'aku_cinta_kamu': -0.843,
#  'aku_keluar_marinir': -0.854,
#  'aku_menemukan_kedamaian': 0.818,
#  'akuapem': 0.272,
#  'akuarium': 0.871,
#  'akuatik': -0.533,
#  'akuisisi': 0.94,
#  'akuisisi_heme': -0.879,
#  'akulturasi': 0.865,
#  'akun': 0.851,
#  'akuntabel': 0.628,
#  'akurasi_angka': 0.288,
#  'akurasi_menunjuk': 0.806,
#  'akurasi_presisi': -0.916,
#  'akurat': 0.824,
#  'akustik': -0.847,
#  'akut': 0.807,
#  'al_dente': 0.212,
#  'aladdin': 0.857,
#  'alaikeda': -0.544,
#  'alam': 0.219,
#  'alam_bawah_sadar': 0.879,
#  'alam_gaib': -0.91,
#  'alam_mimpi': 0.837,
#  'alamaldjin': -0.691,
#  'alamosa': 0.274,
#  'alamshar': 0.84,
#  'alap_alap': -0.531,
#  'alappat': 0.659,
#  'alarm': -0.659,
#  'alarm_keras': -0.151,
#  'alarm_panik': -0.849,
#  'alarplasty': 0.171,
#  'alas': 0.877,
#  'alas_gemerlapnya': 0.867,
#  'alas_vaskular': 0.21,
#  'alasan': 0.659,
#  'alasan_bodoh': -0.903,
#  'alasan_lembam': -0.851,
#  'alastair': 0.511,
#  'alat': -0.845,
#  'alat_airbrush': 0.296,
#  'alat_batu': -0.801,
#  'alat_berkebun': -0.303,
#  'alat_bersayap': -0.984,
#  'alat_buluh': 0.232,
#  'alat_endokarp': -0.829,
#  'alat_kecil': -0.506,
#  'alat_kelamin': 0.802,
#  'alat_lariat': -0.84,
#  'alat_makan_malam': -0.508,
#  'alat_medis': -0.153,
#  'alat_musik_gesek': 0.889,
#  'alat_notarial': 0.919,
#  'alat_pacu_jantung': -0.991,
#  'alat_palet': -0.834,
#  'alat_panggang_listrik': 0.196,
#  'alat_pemotong': 0.901,
#  'alat_pemotong_kawat': 0.905,
#  'alat_pencegah_kehamilan': 0.221,
#  'alat_pendinginkan_air': -0.865,
#  'alat_pengeditan_gambar': -0.651,
#  'alat_pengeriting_rambut': 0.823,
#  'alat_penyemprot': 0.836,
#  'alat_penyemprot_kasar': -0.896,
#  'alat_penyengat': -0.545,
#  'alat_pit': -0.832,
#  'alat_potong': 0.288,
#  'alat_raja': -0.853,
#  'alat_reed_loft': 0.182,
#  'alat_tenun_backstrap': 0.992,
#  'alat_tenun_jacquard': 0.957,
#  'alat_tillage': 0.909,
#  'alat_untuk_mengeluarkan_biji': 0.853,
#  'alberta_spruce': -0.636,
#  'albinisme': -0.984,
#  'albinisme_okulokutaneous': -0.894,
#  'albret': -0.98,
#  'albufera': -0.809,
#  'album_pertama': 0.841,
#  'albumin': -0.968,
#  'albuminuria': -0.866,
#  'alciphron': 0.977,
#  'alcoves': 0.858,
#  'alcyone': 0.884,
#  'aldakton': -0.919,
#  'aldehyde': 0.878,
#  'aldermen': 0.929,
#  'aldobrandino': -0.882,
#  'aleatorik': -0.89,
#  'alegoris': 0.215,
#  'alel': -0.873,
#  'alel_mutan': -0.227,
#  'alencon': 0.563,
#  'alergi': -0.313,
#  'alergi_buruk': -0.974,
#  'alergi_earthnu': -0.85,
#  'alergi_kacang': -0.844,
#  'alergi_kacang_goober': -0.871,
#  'alergi_kacang_tanah': -0.934,
#  'alergi_keras': -0.942,
#  'alergi_mabuk': -0.926,
#  'alergi_makanan': -0.839,
#  'alexander': -0.944,
#  'alexis_bittar': 0.846,
#  'alexis_grace': 0.815,
#  'alexithymia': 0.855,
#  'aleynikov': -0.987,
#  'alfa': 0.933,
#  'alfa_romeo': -0.853,
#  'alfalfa': 0.56,
#  'alfalfa_hay': 0.549,
#  'alfie': -0.845,
#  'alfinez': -0.609,
#  'alfo': -0.921,
#  'alfresco': 0.83,
#  'alfuzosin': -0.496,
#  'alga_planktonik': 0.855,
#  'alginat': 0.195,
#  'algoritma_angka': 0.811,
#  'algoritma_kondensasi': 0.246,
#  'algoritma_pencarian': -0.483,
#  'algoritma_rendering': -0.489,
#  'algy': -0.796,
#  'alhama': -0.875,
#  'ali_pacha': -0.856,
#  'alibech': -0.791,
#  'alick': 0.526,
#  'alimentasi': -0.844,
#  'alinda': 0.899,
#  'aline': 0.871,
#  'aliran': -0.187,
#  'aliran_air_byte': 0.865,
#  'aliran_atap': 0.17,
#  'aliran_batu_stabil': -0.487,
#  'aliran_brace': -0.489,
#  'aliran_byte': 0.897,
#  'aliran_darah': 0.208,
#  'aliran_jet': 0.166,
#  'aliran_juni': 0.892,
#  'aliran_kotoran': -0.166,
#  'aliran_latchmere': 0.492,
#  'aliran_lautan': 0.19,
#  'aliran_magellanic': 0.965,
#  'aliran_masukan': -0.867,
#  'aliran_pendapatan': 0.824,
#  'aliran_polos': -0.697,
#  'aliran_rophy': 0.176,
#  'aliran_stabil': -0.485,
#  'aliran_udara': 0.867,
#  'alis': 0.274,
#  'alis_rendah': 0.871,
#  'alis_tengah': 0.851,
#  'alis_tinggi': 0.866,
#  'aliskiren': -0.824,
#  'alitame': -0.565,
#  'aliterasi': 0.16,
#  'ality': -0.953,
#  'aliweb': -0.53,
#  'aliz_cornet': 0.841,
#  'alizarin': 0.24,
#  'alkimia': 0.849,
#  'alkitab': 0.932,
#  'alkitab_ibrani': 0.165,
#  'alkitab_sendiri': -0.865,
#  'alkohol_monohidric': -0.485,
#  'alkoholisme': -0.516,
#  'allamah': -0.875,
#  'allayer': 0.211,
#  'allen': 0.224,
#  'allergy_serbuk_sari': -0.922,
#  'allholy': -0.67,
#  'allium_cepa': 0.814,
#  'allmouth': 0.291,
#  'allmovie': -0.534,
#  'allodium': -0.859,
#  'allodynia': 0.85,
#  'allograft': -0.832,
#  'alloverplace': -0.545,
#  'allspice': 0.823,
#  'allstar': 0.825,
#  'allthumbs': -0.885,
#  'allviant': -0.82,
#  'almoner': 0.857,
#  'almoner_bengkak': -0.989,
#  'almshouse': -0.867,
#  'alodial': -0.991,
#  'alofon': -0.847,
#  'aloha': 0.833,
#  'alokentris': 0.57,
#  'alopecia': -0.567,
#  'aloplastik': 0.938,
#  'alotrop': 0.143,
#  'alpaka': 0.882,
#  'alpenglow': 0.838,
#  'alprazolam': -0.836,
#  'alprostadil': -0.513,
#  'alrighto': 0.7,
#  'alscassion': 0.831,
#  'alt_rock': -0.152,
#  'altar': 0.198,
#  'altar_kuburan': -0.839,
#  'altazimuth': 0.193,
#  'alteritas': -0.526,
#  'alternaria': -0.189,
#  'alternatif_tol_rendah': 0.809,
#  'alternatif_yang_hemat_biaya': 0.859,
#  'altima': -0.541,
#  'altmer': 0.867,
#  'alto': 0.176,
#  'altruis': 0.889,
#  'altruisme': 0.852,
#  'alu': -0.977,
#  'alula': -0.325,
#  'aluminium': 0.895,
#  'aluminium_anodisasi': 0.801,
#  'alumni': 0.861,
#  'alur': -0.844,
#  'alur_cerita': 0.503,
#  'aluvial': -0.276,
#  'alveolus': 0.701,
#  'alzheimer': -0.94,
#  'amabel': -0.891,
#  'amal': 0.659,
#  'amalekit': -0.64,
#  'aman': 0.329,
#  'aman_untuk_pencuci_piring': 0.135,
#  'amandemen_labouchere': -0.964,
#  'amanita_muscaria': 0.235,
#  'amanita_virosa': -0.836,
#  'amarah_yang_hebat': 0.987,
#  'amarcord': -0.278,
#  'amat_buta': -0.824,
#  'amat_kecil': -0.837,
#  'amat_suci': 0.903,
#  'amaterka_milf': -0.221,
#  'amatir_rapi': -0.531,
#  'amavasya': 0.937,
#  'amaziah': 0.715,
#  'ambang': -0.845,
#  'ambang_batas_gerhana': 0.153,
#  'ambang_jeda': 0.826,
#  'ambang_jendela': 0.821,
#  'ambang_kabin': 0.153,
#  'ambang_laktat': 0.855,
#  'ambang_patio': 0.22,
#  'ambang_pintu': 0.805,
#  'ambedo': -0.167,
#  'ambeien': -0.88,
#  'ambigu': -0.26,
#  'ambil': 0.948,
#  'ambil_bola': -0.921,
#  'ambil_dari_stock': 0.269,
#  'ambil_di_tangan': 0.174,
#  'ambil_gigitan': -0.209,
#  'ambil_hari': 0.623,
#  'ambil_keputusan_akhir': 0.812,
#  'ambil_kredit': -0.9,
#  'ambil_kursi_belakang': -0.502,
#  'ambil_pesawat': 0.174,
#  'ambil_poin': 0.476,
#  'ambil_secara_pribadi': -0.796,
#  'ambil_selamanya': -0.192,
#  'ambil_sidik_jari': -0.879,
#  'ambil_tangan': 0.556,
#  'ambil_tengah_semester': 0.495,
#  'ambil_tidur_siang': 0.843,
#  'ambil_viagra': -0.535,
#  'ambil_waktu_berjam_jam': -0.516,
#  'ambil_wanita': -0.844,
#  'ambing': 0.864,
#  'ambisi': 0.999,
#  'ambisius': 0.987,
#  'ambit': -0.846,
#  'ambivalen': -0.965,
#  'ambiversion': -0.708,
#  'ambled': -0.546,
#  'amblyomma': -0.848,
#  'amblyopic': 0.842,
#  'ambrosia': 0.871,
#  'ambush_mangsa': 0.851,
#  'ambystoma': 0.183,
#  'amcinonide': -0.536,
#  'amelanistik': -0.962,
#  'amercement_amplas': -0.818,
#  'amercement_tune': 0.853,
#  'amergin': 0.29,
#  'amfetamin': 0.144,
#  'amfibi': 0.174,
#  'amfoterisin': 0.628,
#  'amicus': 0.901,
#  'amida': 0.885,
#  'amigdala': -0.95,
#  'amil_nitrat': -0.84,
#  'amiloid': 0.877,
#  'amilorida': -0.531,
#  'amilum': 0.19,
#  'amin': 0.657,
#  'amina': 0.856,
#  'aminoaciduria': -0.536,
#  'aminofilin': -0.916,
#  'aminorex': -0.889,
#  'amir_adalah_seorang_teman': -0.733,
#  'amitabha': 0.827,
#  'amitiza': -0.475,
#  'amittai': -0.645,
#  'amiyumi': 0.975,
#  'amlodipine': -0.825,
#  'amminadab': 0.833,
#  'ammophila': 0.881,
#  'amnesia': 0.883,
#  'amnesiac': -0.89,
#  'amnesti': 0.827,
#  'amnestik': -0.578,
#  'amobarbital': 0.554,
#  'amoeboid': -0.208,
#  'amoniak': -0.833,
#  'amonium': -0.83,
#  'amorf': -0.656,
#  'amorino': 0.683,
#  'amorth': -0.975,
#  'amouage': 0.311,
#  'ampela': 0.925,
#  'ampela_shad': -0.85,
#  'ampelas': -0.827,
#  'amper': 0.837,
#  'amphiesma': -0.851,
#  'amphimallon': 0.305,
#  'amphipod': 0.943,
#  'amphipod_krustasea': 0.855,
#  'amphiprion': 0.911,
#  'amphisbaena': -0.679,
#  'amphisbaenia': -0.636,
#  'ampisilin_sulbaktam': 0.646,
#  'ampiteater': 0.841,
#  'amplas_kasar': -0.816,
#  'amplas_ketat': -0.846,
#  'amplas_pantai': -0.869,
#  'amplitudo': 0.137,
#  'amplitudo_tinggi': -0.917,
#  'amplop': 0.497,
#  'amplop_nuklir': 0.171,
#  'amplop_surat_suara': -0.268,
#  'ampul': -0.871,
#  'ampullary': -0.933,
#  'amputasi': -0.841,
#  'amrita_nektar': -0.508,
#  'amsl': 0.857,
#  'amuba': -0.303,
#  'amunisi': 0.918,
#  'amunisi_nuklir': -0.842,
#  'amunisi_semen': -0.842,
#  'amur_leopard': -0.654,
#  'amurdad': 0.917,
#  'amurense_phellodendron': 0.188,
#  'amyraldisme': -0.497,
#  'anabaptisme': 0.994,
#  'anachrony': -0.495,
#  'anacreontic': -0.885,
#  'anaerobik': -0.316,
#  'anafilaksis': -0.323,
#  'anaforis': 0.824,
#  'anafrodisia': -0.981,
#  'anaglyph': 0.88,
#  'anak': 0.871,
#  'anak_anak': -0.868,
#  'anak_anjing': 0.914,
#  'anak_ayam': -0.182,
#  'anak_ayam_menetas': -0.167,
#  'anak_babi': 0.88,
#  'anak_baru_baru': 0.875,
#  'anak_binatang': 0.862,
#  'anak_bodoh': -0.83,
#  'anak_domba': 0.194,
#  'anak_dusun': -0.181,
#  'anak_keji': 0.918,
#  'anak_kurang_ajar': -0.586,
#  'anak_laki_laki': -0.865,
#  'anak_laki_laki_liston': -0.184,
#  'anak_luar_biasa': 0.959,
#  'anak_nakal': -0.552,
#  'anak_pengambil_air': -0.837,
#  'anak_perusahaan': 0.641,
#  'anak_sekolah': 0.836,
#  'anak_seseorang': 0.978,
#  'anak_sungai': 0.854,
#  'anak_tangga': 0.84,
#  'anak_terlantar': -0.266,
#  'anak_tk': 0.84,
#  'anak_yang_buruk': 0.898,
#  'anak_yang_intens': 0.847,
#  'anak_yang_menakutkan': 0.903,
#  'anak_yang_parah': 0.881,
#  'anak_yang_tak_terkatakan': 0.832,
#  'anak_yatim': -0.155,
#  'anakam': 0.833,
#  'anal': -0.174,
#  'analfabetisme': -0.842,
#  'analis_jungian': 0.188,
#  'analis_khawatir': -0.914,
#  'analis_memperingatkan': 0.847,
#  'analisis': 0.233,
#  'analitik': 0.854,
#  'analog_lanset': 0.302,
#  'analog_nukleosida': 0.213,
#  'analog_purine': 0.163,
#  'analogi': 0.304,
#  'analysand': 0.848,
#  'anamnesis': 0.904,
#  'anamorphic': -0.51,
#  'anangu': 0.219,
#  'anapana': 0.875,
#  'anapest': -0.838,
#  'anapestic': -0.96,
#  'anaplastik': -0.63,
#  'anaplasty': 0.278,
#  'anarki': -0.585,
#  'anasarca': 0.542,
#  'anast': -0.965,
#  'anastomosis': 0.929,
#  'anatta': -0.841,
#  'ancaman': -0.905,
#  'ancaman_dekat': -0.874,
#  'ancaman_hawkish': 0.833,
#  'ancaman_ketakutan': -0.833,
#  'ancaman_nuklir': -0.313,
#  'ancaman_orang_dalam': -0.621,
#  'ancaman_panik': -0.882,
#  'ancaman_yang_bagus': -0.52,
#  'anchoritic': -0.83,
#  'anchusa': 0.488,
#  'anda_akan': 0.946,
#  'anda_cobb': 0.831,
#  'anda_memberikan': -0.87,
#  'andalan': -0.897,
#  'andantino': 0.176,
#  'andewi': 0.573,
#  'androgel': 0.671,
#  'androgen': 0.842,
#  'androgini': 0.878,
#  'andromachi': 0.939,
#  'androsentrisme': -0.95,
#  'andyl': -0.853,
#  'anechoic': -0.495,
#  'anecic': 0.874,
#  'aneh': 0.847,
#  'anehl': -0.836,
#  'anekdot': 0.276,
#  'anekntavda': -0.844,
#  'anel_jeruk': 0.575,
#  'anemia': -0.999,
#  'anemia_aplastik': -0.975,
#  'anemia_makrositik': 0.81,
#  'anemia_megaloblastik': -0.865,
#  'anencephalic': -0.509,
#  'anencephaly': -0.948,
#  'anestesi_inhalasi': -0.987,
#  'anestesi_umum_inhalasi': -0.915,
#  'aneuploidy': 0.862,
#  'aneurisma_mikotik': -0.843,
#  'anfo': -0.863,
#  'ang_jong_ekonomis': 0.87,
#  'anggapan': -0.86,
#  'anggaplah_uang_yang_tidak_seimbang': 0.606,
#  'anggaran': 0.807,
#  'anggaran_rewel': -0.524,
#  'anggaran_yang_rendah': 0.204,
#  'anggota': 0.564,
#  'anggota_dewan_municipal': -0.913,
#  'anggota_paduan_suara': 0.875,
#  'anggota_parlemen': -0.806,
#  'anggota_sebuah_suku': -0.901,
#  'anggota_suku': 0.937,
#  'anggrek': 0.139,
#  'anggukan': 0.272,
#  'anggun': 0.801,
#  'anggur': -0.498,
#  'anggur_murah': -0.508,
#  'anggur_yang_direnungkan': 0.252,
#  'angin': -0.659,
#  'angin_azide': -0.806,
#  'angin_baru': -0.855,
#  'angin_benjolan': 0.861,
#  'angin_berlapis': 0.381,
#  'angin_bertabrakan': -0.806,
#  'angin_beruntun': 0.881,
#  'angin_bocal': 0.802,
#  'angin_buang_buang': 0.833,
#  'angin_bung': 0.799,
#  'angin_fells': 0.82,
#  'angin_gembur': 0.799,
#  'angin_hembusan': 0.843,
#  'angin_kencang': 0.903,
#  'angin_lilin': 0.835,
#  'angin_menderu': 0.812,
#  'angin_menyia_nyiakan': 0.793,
#  'angin_panas': -0.797,
#  'angin_pasat': 0.826,
#  'angin_puyuh': -0.859,
#  'angin_rampas': 0.843,
#  'angin_sakal': -0.879,
#  'angin_segar': 0.849,
#  'angin_semua': 0.804,
#  'angin_sepoi_sepoi': 0.868,
#  'angin_surya': 0.219,
#  'angin_tanah_liat': 0.862,
#  'angin_tongkat': 0.82,
#  'angin_topan': -0.194,
#  'angin_turun': 0.517,
#  'angin_yang_memuliakan': 0.376,
#  'angina': -0.21,
#  'angioedema': -0.295,
#  'angiofibroma': -0.871,
#  ...}

# %%
def calculate_sentiment_score(review):
  score = 0
  words = review.split()  # Pisahkan ulasan menjadi kata-kata
  index = 0
  for word in words:
    if word in senticnet_dict:  # Cek apakah kata ada di SenticNet
      cur_score = senticnet_dict[word]
      if ('tidak' in words[max(index-3, 0):index]):
        cur_score *= -1
      print(word, cur_score)
      score += cur_score  # Tambahkan skor sentimen dari SenticNet
    index += 1
  if (score > 0):
    sentiment = 2 #positif
  elif (score == 0):
    sentiment = 1 #netral
  else:
    sentiment = 0 #negatif
  return score, sentiment

# %%
test = lexicon_df[:4]['Cleaned'].values[2]
ori = df[:4]['Review'].values[2]
print(ori)
print(test)
calculate_sentiment_score(test)
# Out:
# [SOLD]baru pertama kali nyoba dan beli karna liat yt di famaledaily trs aku pake pertama kali dimalam hari besok pagi nya bruntusan☹️ trs aku pake lagi dipagi dan malam eh lusa nya makin memerah😭 jadi aku mutusin untuk berhenti karna spt nya gacocok di aku dan aku mau ... Read more
# soldbaru kali coba beli lihat yt famaledaily pakai kali malam besok pagi nya pakai pagi malam eh lusa nya putus henti nya gacocok read more
# lihat 0.287
# pakai 0.923
# malam 0.808
# pakai 0.923
# malam 0.808
# putus -0.873
# (2.8759999999999994, 2)

# %%
df[["Score", "Sentiment-Lexicon"]] = [calculate_sentiment_score(x) for x in tqdm(df['Cleaned'].values)]
# Out:
#   0%|          | 0/8646 [00:00<?, ?it/s]

# %%
lexicon_df = df[['Cleaned', 'Sentiment-Lexicon', 'Score']]
lexicon_df.head()
# Out:
#                                              Cleaned  Sentiment-Lexicon  Score
# 0  benar kerja melembabkan banget tidak lebaygak ...                2.0  0.197
# 1  tidak cocok banget bikin muka bruntusan langsu...                0.0 -0.136
# 2  soldbaru kali coba beli lihat yt famaledaily p...                2.0  2.876
# 3  enak sih muka kering lembab pagi bangun kenyal...                2.0  4.637
# 4  sold out preloved halo preloved ya pakai mingg...                0.0 -0.520
